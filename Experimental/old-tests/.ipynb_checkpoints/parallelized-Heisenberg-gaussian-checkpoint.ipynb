# %%
import sys
path='/home/tomas/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/'

sys.path.insert(1, path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qutip
import scipy.linalg as linalg
import time
from multiprocessing import Pool
from itertools import product
from typing import Optional

import alpsqutip.parallelized_functions_and_workers as plME

from alpsqutip import (build_system, list_models_in_alps_xml,
                       list_geometries_in_alps_xml, graph_from_alps_xml,
                       model_from_alps_xml,
                       restricted_maxent_toolkit as me)

from alpsqutip.operators.states.utils import safe_exp_and_normalize ## function used to safely and robustly map K-states to states

from alpsqutip.scalarprod import fetch_covar_scalar_product
from alpsqutip.operators.states.gibbs import GibbsDensityOperator, GibbsProductDensityOperator

# %%
from alpsqutip.operators.arithmetic import (
    ScalarOperator,
    LocalOperator,
    OneBodyOperator,
    Operator,
    ProductOperator,
    ScalarOperator,
    SumOperator,
    QutipOperator
)

from alpsqutip.operators.simplify import simplify_sum_operator

# %%
params={}

params['size']=4
params['Jx']=1.; params['Jy'] = .75*params['Jx']; params['Jz']=1.05*params['Jx']

from scipy.optimize import root, fsolve
Ffactor=np.real(max(np.roots(np.poly1d([1, 0, -(params['Jx']*params['Jy']+params['Jx']*params['Jy']+params['Jy']*params['Jz']), 
                           -2*params['Jx']*params['Jy']*params['Jz']]))))
chi_y=fsolve(lambda x,y: x*np.arcsinh(x)-np.sqrt(x**2+1)-y, 1e-1, args=(0))[0]
vLR=4*Ffactor*chi_y

# %%
system = build_system(geometry_name="open chain lattice", model_name="spin", 
                      L=params['size'], J=1)

sites = [s for s in system.sites]
sx_ops = [system.site_operator("Sx", f'1[{a}]') for a in range(len(sites))]
sy_ops = [system.site_operator("Sy", f'1[{a}]') for a in range(len(sites))]
sz_ops = [system.site_operator("Sz", f'1[{a}]') for a in range(len(sites))]

idop = [system.site_operator('identity@1[' + str(a) + ']') for a in range(len(system.sites))]
from functools import reduce
idop = reduce(Operator.__mul__, idop)

H_xx = 0

# Only nearest-neighbor (r = 1) and no Sz-Sz terms
for i in range(params['size'] - 1):
    Jx_ij = 1.0  # or params['Jx'] if defined
    Jy_ij = 1.0  # or params['Jy'] if defined

    term = (
        Jx_ij * sx_ops[i] * sx_ops[i + 1] +
        Jy_ij * sy_ops[i] * sy_ops[i + 1]
    )
    
    H_xx += term

H = H_xx.simplify()
# Out:
# loading model spin  over graph open chain lattice

# %%
obs_SzA = sum(sz for sz in sz_ops)
HBB0=[idop, system.site_operator("Sx@1[0]")*system.site_operator("Sx@1[1]")
      +system.site_operator("Sy@1[0]")*system.site_operator("Sy@1[1]"),
     system.site_operator("Sx@1[1]")*system.site_operator("Sx@1[2]")
      +system.site_operator("Sy@1[1]")*system.site_operator("Sy@1[2]")]

phi0 = np.array([.0, .25, .25])
K0 = phi0@HBB0
sigma0 = GibbsDensityOperator(K0)
phi0[0] = np.log(sigma0.tr())
K0 = phi0@HBB0
sigma0 = GibbsDensityOperator(K0)
[(sigma0 * op).tr() for op in sz_ops]
# Out:
# [(2.0816681711721685e-17+0j),
#  (-6.938893903907228e-18+0j),
#  (6.938893903907228e-18+0j),
#  0.0]

# %%
## exact dynamics
tgt_obs = system.site_operator("Sx@1[0]")*system.site_operator("Sx@1[1]")
tgt_obs += +1*system.site_operator("Sy@1[0]")*system.site_operator("Sy@1[1]")
tgt_obs = tgt_obs.simplify()

timespan=np.linspace(.0, 100/vLR,100)
evs_obs_ex=qutip.mesolve(H=H.to_qutip(), rho0=sigma0.to_qutip()
                         , tlist=timespan, e_ops=[tgt_obs.to_qutip()])

# %%
evs_obs_ex.expect
# Out:
# [array([-0.03116887, -0.03116886, -0.03116866, -0.03116783, -0.03116563,
#         -0.03116103, -0.0311527 , -0.03113911, -0.03111846, -0.03108875,
#         -0.03104778, -0.03099323, -0.03092264, -0.03083346, -0.0307231 ,
#         -0.03058895, -0.03042841, -0.03023897, -0.03001818, -0.02976376,
#         -0.02947358, -0.0291457 , -0.02877845, -0.0283704 , -0.02792043,
#         -0.02742773, -0.02689185, -0.02631266, -0.02569045, -0.02502586,
#         -0.02431994, -0.02357412, -0.02279023, -0.02197049, -0.02111747,
#         -0.02023414, -0.01932378, -0.01839001, -0.01743672, -0.0164681 ,
#         -0.01548854, -0.01450266, -0.01351522, -0.0125311 , -0.0115553 ,
#         -0.0105928 , -0.00964864, -0.00872776, -0.00783505, -0.00697525,
#         -0.00615295, -0.0053725 , -0.00463802, -0.00395335, -0.00332199,
#         -0.00274713, -0.00223155, -0.00177765, -0.00138743, -0.00106242,
#         -0.00080375, -0.00061207, -0.0004876 , -0.0004301 , -0.00043889,
#         -0.00051285, -0.00065046, -0.00084978, -0.00110851, -0.00142398,
#         -0.00179322, -0.00221294, -0.00267962, -0.0031895 , -0.00373866,
#         -0.00432302, -0.0049384 , -0.00558057, -0.00624527, -0.00692825,
#         -0.00762537, -0.00833252, -0.00904578, -0.00976138, -0.01047575,
#         -0.01118558, -0.01188779, -0.0125796 , -0.01325852, -0.01392239,
#         -0.0145694 , -0.01519804, -0.01580716, -0.01639598, -0.01696402,
#         -0.01751115, -0.01803756, -0.01854373, -0.01903045, -0.01949875])]

# %%
simulations={}
sp_local = fetch_covar_scalar_product(sigma0)

from scipy.linalg import cho_solve, cho_factor
       
simulations[1] = {
    "parms":{
    "chosen_depth": 6,
    "m0": 3,
    "eps": 1e-3,
    },
  "saved_cut_times_index_ell":[0],
   "no_acts_ell" : [0],
    "local_bound_error_ell":[],
    "spectral_norm_Hij_tensor_ell":[],
    "instantaneous_w_errors":[],
} 

current_simulation = simulations[1]
current_simulation_parms = current_simulation["parms"]
chosen_depth = current_simulation_parms["chosen_depth"]
eps_tol = current_simulation_parms["eps"]
m0 = current_simulation_parms["m0"]
num_workers = 1

# %%
sp_local_non_act=me.fetch_covar_scalar_product(sigma=sigma0) ## choosing of the scalar product
HBB_ell_non_act=plME.parallelized_real_time_projection_of_hierarchical_basis(
    generator=H,
    seed_op=tgt_obs,
    sigma_ref=GibbsDensityOperator(K0),
    nmax=m0,
    deep=chosen_depth,
    num_workers=num_workers,
    tidy_thresh = 1e-20
)

Gram_matrix_non_act = plME.parallel_gram_matrix_fine(basis = HBB_ell_non_act, 
                                                       sp = sp_local_non_act,
                                                       num_workers=num_workers)
R_non_act = np.linalg.cholesky(Gram_matrix_non_act).conj().T

b_orth= linalg.inv(R_non_act.T) @ HBB_ell_non_act

Hij_tensor_non_act_non_orth = plME.compute_Hij_tensor_non_orth(
    basis = HBB_ell_non_act, 
    generator = H, 
    sp = sp_local_non_act,
    sigma_ref = sigma0,
    nmax = m0,
    Gram = Gram_matrix_non_act,
            num_workers=num_workers
)

Hij_tensor_non_act = (linalg.inv(R_non_act).T 
                  @ Hij_tensor_non_act_non_orth 
                  @ linalg.inv(R_non_act)) ### In this convention for R_act, the orthonormal Hij_orth is
                                           ### Hij_orth = (R**-1).T @ Hij_non_orth @ (R**-1)
    
phi0_proj_non_act = np.array([sp_local_non_act(tgt_obs, op) for op in b_orth])
new_obs_local=(phi0_proj_non_act @ b_orth).simplify()
print("Fita: Check", ((new_obs_local.to_qutip() - tgt_obs.to_qutip())).norm())

phi_at_timet = np.array([
    (linalg.expm(Hij_tensor_non_act*(t-.0)) @ phi0_proj_non_act) for t in timespan
])

K_at_timet = [(phit @ b_orth).simplify() for phit in phi_at_timet]
#sigma_at_timet = [GibbsDensityOperator(Kt) for Kt in K_at_timet]
evs_non_act = [(GibbsDensityOperator(K0).to_qutip() * obs_local.to_qutip()).tr()
               for obs_local in K_at_timet]
# Out:
# Fita: Check 1.1123509293162326e-15

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

m=20

# Plot both curves with labels
plt.plot(timespan[:m], evs_obs_ex.expect[0][:m], label=r'$\langle O(t) \rangle$ (XX evolution)', lw=2)
plt.plot(timespan[:m], evs_non_act[:m], label=r'$\langle O(t) \rangle$ (Max-Ent ell=10, m=2)', lw=2, linestyle='--')

# Labels and title
plt.xlabel(r'Time $tJ$', fontsize=14)
plt.ylabel(r'Expectation $\langle O(t) \rangle$', fontsize=14)
plt.title('Observable Dynamics under XX Evolution', fontsize=16)

# Legend and grid
plt.legend(fontsize=12)
plt.grid(True, linestyle=':', alpha=0.5)

# Ticks and layout
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()

plt.show()

# %%
HBB_ell_non_act[-1]
# Out:
# (
# qutip interface operator for 1 x
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0.+0.j       0.+0.j       0.+0.j       0.+0.j       0.+0.j
#   0.+0.j       0.+0.j       0.+0.j      ]
#  [0.+0.j       0.+0.j       0.+0.j       0.+0.j       0.+0.015625j
#   0.+0.j       0.+0.j       0.+0.j      ]
#  [0.+0.j       0.+0.j       0.+0.j       0.+0.j       0.+0.j
#   0.+0.j       0.+0.j       0.+0.j      ]
#  [0.+0.j       0.+0.j       0.+0.j       0.+0.j       0.+0.j
#   0.+0.j       0.-0.015625j 0.+0.j      ]
#  [0.+0.j       0.-0.015625j 0.+0.j       0.+0.j       0.+0.j
#   0.+0.j       0.+0.j       0.+0.j      ]
#  [0.+0.j       0.+0.j       0.+0.j       0.+0.j       0.+0.j
#   0.+0.j       0.+0.j       0.+0.j      ]
#  [0.+0.j       0.+0.j       0.+0.j       0.+0.015625j 0.+0.j
#   0.+0.j       0.+0.j       0.+0.j      ]
#  [0.+0.j       0.+0.j       0.+0.j       0.+0.j       0.+0.j
#   0.+0.j       0.+0.j       0.+0.j      ]]
#   +qutip interface operator for 1 x
# Quantum object: dims=[[2, 2, 2], [2, 2, 2]], shape=(8, 8), type='oper', dtype=Dense, isherm=True
# Qobj data =
# [[0.+0.j         0.+0.j         0.+0.j         0.+0.j
#   0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.+0.j
#   0.-0.01953125j 0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.+0.j
#   0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.+0.j
#   0.+0.j         0.+0.j         0.+0.01953125j 0.+0.j        ]
#  [0.+0.j         0.+0.01953125j 0.+0.j         0.+0.j
#   0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.+0.j
#   0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.-0.01953125j
#   0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]
#  [0.+0.j         0.+0.j         0.+0.j         0.+0.j
#   0.+0.j         0.+0.j         0.+0.j         0.+0.j        ]]
# )
