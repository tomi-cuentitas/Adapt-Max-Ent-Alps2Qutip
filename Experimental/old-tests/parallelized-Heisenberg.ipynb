# %%
import sys
path='/home/tomas/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/'

sys.path.insert(1, path)

# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qutip
import scipy.linalg as linalg
import time
from multiprocessing import Pool
from itertools import product
from typing import Optional

import alpsqutip.parallelized_functions_and_workers as plME

from alpsqutip import (build_system, list_models_in_alps_xml,
                       list_geometries_in_alps_xml, graph_from_alps_xml,
                       model_from_alps_xml,
                       restricted_maxent_toolkit as me)

from alpsqutip.operators.states.utils import safe_exp_and_normalize ## function used to safely and robustly map K-states to states

from alpsqutip.scalarprod import fetch_covar_scalar_product
from alpsqutip.operators.states.gibbs import GibbsDensityOperator, GibbsProductDensityOperator

# %%
from alpsqutip.operators.arithmetic import (
    ScalarOperator,
    LocalOperator,
    OneBodyOperator,
    Operator,
    ProductOperator,
    ScalarOperator,
    SumOperator,
    QutipOperator
)

from alpsqutip.operators.simplify import simplify_sum_operator

# %%
params={}

params['size']=7
params['Jx']=1.; params['Jy'] = .75*params['Jx']; params['Jz']=1.05*params['Jx']

from scipy.optimize import root, fsolve
Ffactor=np.real(max(np.roots(np.poly1d([1, 0, -(params['Jx']*params['Jy']+params['Jx']*params['Jy']+params['Jy']*params['Jz']), 
                           -2*params['Jx']*params['Jy']*params['Jz']]))))
chi_y=fsolve(lambda x,y: x*np.arcsinh(x)-np.sqrt(x**2+1)-y, 1e-1, args=(0))[0]
vLR=4*Ffactor*chi_y

# %%
system=build_system(geometry_name= "open chain lattice",model_name="spin", 
                    L=params['size'], J=1)

sites=[s for s in system.sites]
sx_ops=[system.site_operator("Sx", '1[' + str(a) + ']') for a in range(len(system.sites))]
sy_ops=[system.site_operator("Sy", '1[' + str(a) + ']') for a in range(len(system.sites))]
sz_ops=[system.site_operator("Sz", '1[' + str(a) + ']') for a in range(len(system.sites))]

idop = [system.site_operator('identity@1[' + str(a) + ']') for a in range(len(system.sites))]
from functools import reduce
idop = reduce(Operator.__mul__, idop)

#Iz = sum(sz_ops)
H_nn = 0  # Proches voisins
H_lr = 0  # Longue portée

from itertools import combinations

for i, j in combinations(range(params['size']), 2):
    r = abs(i - j)
    Jx_ij = params['Jx'] / r**3
    Jy_ij = params['Jy'] / r**3
    Jz_ij = params['Jz'] / r**3

    term = (
        Jx_ij * sx_ops[i] * sx_ops[j]
        + Jy_ij * sy_ops[i] * sy_ops[j]
        + Jz_ij * sz_ops[i] * sz_ops[j]
    )

    if r == 1:
        H_nn += term  # Interaction de voisins immédiats
    else:
        H_lr += term  # Interaction à longue portée
        
H = H_nn + H_lr
H = H.simplify()
# Out:
# loading model spin  over graph open chain lattice

# %%
z = np.random.rand()
z
# Out:
# 0.5836401626659918

# %%
obs_SzA = sum(sz for sz in sz_ops)
HBB0=[idop]+[sz for sz in sz_ops]

phi0 = np.array([.0] + [-1.5+np.random.rand() for _ in HBB0[1:]])

K0 = me.k_state_from_phi_basis(phi0, HBB0).simplify()
sigma0 = GibbsProductDensityOperator(K0)
phi0[0] = np.log(sigma0.tr())
K0 = me.k_state_from_phi_basis(phi0, HBB0).simplify()
sigma0 = GibbsProductDensityOperator(K0)

tgt_obs = obs_SzA
[(sigma0 * op).tr().real for op in sz_ops]
# Out:
# [0.3072783835084674,
#  0.18312028537213035,
#  0.2532508867770693,
#  0.2314841016348639,
#  0.15740700838890698,
#  0.2774416165669239,
#  0.1443569412935587]

# %%
## exact dynamics

timespan=np.linspace(.0, 1200/vLR,300)
evs_obs_ex=qutip.mesolve(H=H.to_qutip(), rho0=sigma0.to_qutip(), tlist=timespan, e_ops=[tgt_obs.to_qutip()])

# %%
simulations={}
tgt_obs = obs_SzA
sp_local = fetch_covar_scalar_product(sigma0)

from scipy.linalg import cho_solve, cho_factor
       
simulations[1] = {
    "parms":{
    "chosen_depth": 5,
    "m0": 3,
    "eps": 1e-3,
    },
  "saved_cut_times_index_ell":[0],
   "no_acts_ell" : [0],
    "local_bound_error_ell":[],
    "spectral_norm_Hij_tensor_ell":[],
    "instantaneous_w_errors":[],
} 

current_simulation = simulations[1]
current_simulation_parms = current_simulation["parms"]
chosen_depth = current_simulation_parms["chosen_depth"]
eps_tol = current_simulation_parms["eps"]
m0 = current_simulation_parms["m0"]

# %%
local_bound_error_ell = []
simulations[1]["evs"] = [(sigma0 * tgt_obs).tr()]  # initial observable expectation

sp_local = fetch_covar_scalar_product(sigma=sigma0)
local_t_value = 0.0

# Initial bass construction and orthogonalization
HBB_ell_act = plME.parallelized_real_time_projection_of_hierarchical_basis(
    generator=H,
    seed_op=obs_SzA,
    sigma_ref=sigma0,
    m_max=m0,
    deep=chosen_depth,
    num_workers=6
)

orth_basis_act, R_act, Gram_matrix_act = plME.orthogonalize_basis_parallel_process(
    basis = HBB_ell_act,
    sp = sp_local, 
    max_workers =9,
            return_orth_basis=True,
)

Hij_tensor_act_non_orth = plME.compute_Hij_tensor_non_orth(
    basis = HBB_ell_act, 
    generator = H, 
    sp = sp_local,
    sigma_ref = sigma0,
    m_max = m0,
    Gram = Gram_matrix_act,
            num_workers=6
)

Hij_tensor_act = (linalg.inv(R_act).T 
                  @ Hij_tensor_act_non_orth 
                  @ linalg.inv(R_act)) ### In this convention for R_act, the orthonormal Hij_orth is
                                       ### Hij_orth = (R**-1).T @ Hij_non_orth @ (R**-1)

phi0_proj_act = np.array([sp_local(tgt_obs, op) for op in orth_basis_act])
new_obs_local=sum(phi0a * opa for phi0a, opa in zip(phi0_proj_act, orth_basis_act)).simplify() ### same here
print("Fita: Check", ((new_obs_local.to_qutip() - tgt_obs.to_qutip())).norm())

for t in timespan[1:]:
    start = time.time()
    
    if list(timespan).index(t) >= 30:
        m0 = m0+1
    
    delta_t = t - local_t_value
    exp_H = linalg.expm(delta_t * Hij_tensor_act)
    phi_local = np.real(exp_H @ phi0_proj_act)
    
    print(f"A. phi-local {time.time() - start:.2f}s");    start = time.time()
    
    obs_local = sum(c * op for c, op in zip(phi_local, orth_basis_act)).simplify()
    
    print(f"B. obs-local {time.time() - start:.2f}s");    start = time.time()
    
    simulations[1]["evs"].append((sigma0.to_qutip() * obs_local.to_qutip()).tr())
    
    print(f"C. Ev {time.time() - start:.2f}s");    start = time.time()
    
    # Compute the local bound error ratio
    numerator = me.m_th_partial_sum(phi=phi_local, m=2)
    denominator = me.m_th_partial_sum(phi=phi_local, m=0)
    local_bound_error_ell.append(numerator / denominator)
    
    # Check if error is above threshold, trigger basis update
    if abs(local_bound_error_ell[-1]) >= eps_tol:
        local_t_value = t
        print(f"a. Renormalization at t={list(timespan).index(t)}")
        
        if list(timespan).index(t)%20 == 0:
            
            def f(lambda_):
                rho = (-lambda_ * tgt_obs.to_qutip()).expm() / ((-lambda_ * tgt_obs.to_qutip()).expm()).tr()
                return (rho * tgt_obs.to_qutip()).tr().real
            
            mu = (sigma0.to_qutip() * obs_local.to_qutip()).tr().real  # or however you've computed it

            from scipy.optimize import root_scalar
            result = root_scalar(lambda l: f(l) - mu, bracket=[-10, 10])
            lambda_star = result.root
            
            sp_local = fetch_covar_scalar_product(sigma=(GibbsProductDensityOperator(lambda_star * tgt_obs)))
        
        start = time.time()
        HBB_ell_act = plME.parallelized_real_time_projection_of_hierarchical_basis(
                generator=H,
                seed_op=obs_local,
                sigma_ref=sigma0,
                m_max=m0,
                deep=chosen_depth,
                num_workers=6
        )
        print(f"b. HBB_ell_act, {time.time() - start:.6f}s")
        
        start = time.time()
        
        orth_basis_act, R_act, Gram_matrix_act = plME.orthogonalize_basis_parallel_process(
            basis = HBB_ell_act,
            sp = sp_local, 
            max_workers =12,
            return_orth_basis=True
        )
        
        print(f"c. orth basis act, {time.time() - start:.6f}s")
        
        start = time.time()
        
        Hij_tensor_act_non_orth = plME.compute_Hij_tensor_non_orth(
            basis = HBB_ell_act, 
            generator = H, 
            sp = sp_local,
            sigma_ref = sigma0,
            m_max = m0,
            Gram = Gram_matrix_act,
            num_workers=6
        )
            
        print(f"d. Hij-tensor-act, {time.time() - start:.6f}s")
        Hij_tensor_act = linalg.inv(R_act).T @ Hij_tensor_act_non_orth @ linalg.inv(R_act)
        phi0_proj_act = np.array([sp_local(obs_local, op) for op in orth_basis_act])
        new_obs_local=sum(phi0a * opa for phi0a, opa in zip(phi0_proj_act, orth_basis_act)).simplify() ### same here
        print("Fita: Check", ((new_obs_local.to_qutip() - obs_local.to_qutip())).norm())
    else:
        # If error below tolerance, keep current basis and coefficients
        pass
# Out:
# Fita: Check 5.668525467500855e-15
# A. phi-local 0.00s
# B. obs-local 0.01s
# C. Ev 0.19s
# A. phi-local 0.00s
# B. obs-local 0.03s
# C. Ev 0.05s
# A. phi-local 0.00s
# B. obs-local 0.02s
# C. Ev 0.05s
# a. Renormalization at t=3
# b. HBB_ell_act, 37.480661s
# c. orth basis act, 104.390661s
# d. Hij-tensor-act, 6.600963s
# Fita: Check 4.488001039923001e-14
# A. phi-local 0.01s
# B. obs-local 0.03s
# C. Ev 0.12s
# A. phi-local 0.00s
# B. obs-local 0.02s
# C. Ev 0.06s
# A. phi-local 0.00s
# B. obs-local 0.02s
# C. Ev 0.06s
# a. Renormalization at t=6
# b. HBB_ell_act, 43.731752s
# c. orth basis act, 112.812523s
# d. Hij-tensor-act, 8.594482s
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x75b9de961b20>>
# Traceback (most recent call last):
#   File "/home/tomas/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 123
#     121 print(f"d. Hij-tensor-act, {time.time() - start:.6f}s")
#     122 Hij_tensor_act = linalg.inv(R_act).T @ Hij_tensor_act_non_orth @ linalg.inv(R_act)
# --> 123 phi0_proj_act = np.array([sp_local(obs_local, op) for op in orth_basis_act])
#     124 new_obs_local=sum(phi0a * opa for phi0a, opa in zip(phi0_proj_act, orth_basis_act)).simplify() ### same here
#     125 print("Fita: Check", ((new_obs_local.to_qutip() - obs_local.to_qutip())).norm())
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/scalarprod/build.py:84, in CovarianceScalarProduct.__call__(self, op1, op2)
#      82 if op1_herm:
#      83     if op2_herm:
# ---> 84         return real(sigma.expect(op1 * op2))
#      85     op1_dag = op1
#      86 else:
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/basic.py:143, in Operator.__mul__(self, factor)
#     141 func = dispatch_table.get((type(self), type(factor)), None)
#     142 if func is not None:
# --> 143     return func(self, factor)
#     144 # Now, look for cases associated to the class hierarchy
#     145 func = find_arithmetic_implementation(self, factor, dispatch_table)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/register_ops.py:542, in _(x_op, y_op)
#     535 @Operator.register_mul_handler(
#     536     tuple(
#     537         (sum_type_1, sum_type_2) for sum_type_1 in SUM_TYPES for sum_type_2 in SUM_TYPES
#     538     )
#     539 )
#     540 def _(x_op: SumOperator, y_op: SumOperator):
#     541     system = x_op.system * y_op.system if x_op.system else y_op.system
# --> 542     terms = tuple(
#     543         factor_x * factor_y for factor_x in x_op.terms for factor_y in y_op.terms
#     544     )
#     545     if len(terms) == 0:
#     546         return ScalarOperator(0, system)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/register_ops.py:543, in <genexpr>(.0)
#     535 @Operator.register_mul_handler(
#     536     tuple(
#     537         (sum_type_1, sum_type_2) for sum_type_1 in SUM_TYPES for sum_type_2 in SUM_TYPES
#     538     )
#     539 )
#     540 def _(x_op: SumOperator, y_op: SumOperator):
#     541     system = x_op.system * y_op.system if x_op.system else y_op.system
#     542     terms = tuple(
# --> 543         factor_x * factor_y for factor_x in x_op.terms for factor_y in y_op.terms
#     544     )
#     545     if len(terms) == 0:
#     546         return ScalarOperator(0, system)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/basic.py:143, in Operator.__mul__(self, factor)
#     141 func = dispatch_table.get((type(self), type(factor)), None)
#     142 if func is not None:
# --> 143     return func(self, factor)
#     144 # Now, look for cases associated to the class hierarchy
#     145 func = find_arithmetic_implementation(self, factor, dispatch_table)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/register_ops.py:571, in _(x_op, y_op)
#     558 @Operator.register_mul_handler(
#     559     [
#     560         (sum_type, op_type)
#    (...)
#     568 )
#     569 def _(x_op: SumOperator, y_op: Operator):
#     570     system = x_op.system * y_op.system if x_op.system else y_op.system
# --> 571     terms = tuple(factor_x * y_op for factor_x in x_op.terms)
#     572     if len(terms) == 0:
#     573         return ScalarOperator(0, system)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/register_ops.py:571, in <genexpr>(.0)
#     558 @Operator.register_mul_handler(
#     559     [
#     560         (sum_type, op_type)
#    (...)
#     568 )
#     569 def _(x_op: SumOperator, y_op: Operator):
#     570     system = x_op.system * y_op.system if x_op.system else y_op.system
# --> 571     terms = tuple(factor_x * y_op for factor_x in x_op.terms)
#     572     if len(terms) == 0:
#     573         return ScalarOperator(0, system)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/basic.py:143, in Operator.__mul__(self, factor)
#     141 func = dispatch_table.get((type(self), type(factor)), None)
#     142 if func is not None:
# --> 143     return func(self, factor)
#     144 # Now, look for cases associated to the class hierarchy
#     145 func = find_arithmetic_implementation(self, factor, dispatch_table)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/register_ops.py:1025, in _(x_op, y_qutip_op)
#    1007 @Operator.register_mul_handler(
#    1008     [
#    1009         (
#    (...)
#    1022     y_qutip_op: QutipOperator,
#    1023 ):
#    1024     """Multiply an operator and a number  or a Qobj"""
# -> 1025     return x_op.to_qutip_operator() * y_qutip_op
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/basic.py:143, in Operator.__mul__(self, factor)
#     141 func = dispatch_table.get((type(self), type(factor)), None)
#     142 if func is not None:
# --> 143     return func(self, factor)
#     144 # Now, look for cases associated to the class hierarchy
#     145 func = find_arithmetic_implementation(self, factor, dispatch_table)
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/register_ops.py:1067, in mul_qutip_operator_qutip_operator(x_op, y_op)
#    1065 names_set.update(y_names)
#    1066 block = tuple(sorted(names_set))
# -> 1067 operator_qutip = x_op.to_qutip(block) * y_op.to_qutip(block)
#    1068 return QutipOperator(
#    1069     operator_qutip,
#    1070     system,
#    1071     names={site: i for i, site in enumerate(block)},
#    1072     prefactor=1,
#    1073 )
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/qutip.py:292, in QutipOperator.to_qutip(self, block)
#     282 """
#     283 Return a qutip operator representing the action over
#     284 sites in block.
#    (...)
#     289 `self.operator`.
#     290 """
#     291 site_names_dict = self.site_names
# --> 292 site_names = sorted(site_names_dict, key=lambda x: site_names_dict[x])
#     293 system = self.system
#     294 sites = system.sites
#
# File ~/Ulmer-Berechnung/alps2qutipplus-april/alps2qutipplus-main/alpsqutip/operators/qutip.py:292, in QutipOperator.to_qutip.<locals>.<lambda>(x)
#     282 """
#     283 Return a qutip operator representing the action over
#     284 sites in block.
#    (...)
#     289 `self.operator`.
#     290 """
#     291 site_names_dict = self.site_names
# --> 292 site_names = sorted(site_names_dict, key=lambda x: site_names_dict[x])
#     293 system = self.system
#     294 sites = system.sites
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Création de la figure et des axes principaux
fig, ax = plt.subplots(figsize=(6, 6))

n = 1
m = 37

# --- Courbe principale: observable exact + simulation ---
ax.plot(timespan[:m]*vLR, evs_obs_ex.expect[0][:m],
        label='Exact', color="blue", linestyle='dashdot', linewidth=1)

l = simulations[1]["parms"]["chosen_depth"]
m0 = simulations[1]["parms"]["m0"]
eps = simulations[1]["parms"]["eps"]

label_sim1 = fr'Heisenberg $(\ell, m_0, \epsilon) = ({l}, {m0}, {eps})$'
ax.plot(timespan[:m]*vLR, simulations[1]["evs"][:m],
        label=label_sim1, color='red', linestyle='--', marker='D', linewidth=1)

# --- Inset: Delta courbe ---
weigthed_fidelity = np.array([abs(evs_obs_ex.expect[0][i] - simulations[1]["evs"][i])/abs(evs_obs_ex.expect[0][i])
                             for i in range(0, m)])
inset_ax = inset_axes(ax, width="40%", height="30%", loc='lower left', borderpad=3)
inset_ax.plot(timespan[:m]*vLR,weigthed_fidelity,
              color="black", linestyle='solid', linewidth=1)
inset_ax.set_title(r'$\Delta\ (\%/100)$', fontsize=10)

inset_ax.tick_params(labelsize=8)
inset_ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

# --- Style global ---
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(direction='out', length=6, width=2, which='major', grid_alpha=0.6)
ax.grid(True, which='major', linestyle='--', linewidth=0.75, alpha=0.7)
ax.legend(frameon=False, loc='upper right')

# Axe secondaire en haut
ax1 = ax.twiny()
ax1.set_xlim(timespan[0], timespan[-1])
ax.set_xlabel(r'$t v_{\rm LR} \, [L]$')
ax1.set_xlabel(r'$t \, [{\rm arb. units}]$')

# Titre
plt.title(r'non-local Hamiltonian, $L={}$, $J_x={}$, $v_{{\rm LR}}={}$'.format(
    params['size'], 
    round(params['Jx'], 3), 
    round(vLR, 3)
))

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# Création de la figure et des axes principaux
fig, ax = plt.subplots(figsize=(6, 6))

n = 1
m = 63

# --- Courbe principale: observable exact + simulation ---
ax.plot(timespan[:m]*vLR, evs_obs_ex.expect[0][:m],
        label='Exact', color="blue", linestyle='dashdot', linewidth=1)

l = simulations[1]["parms"]["chosen_depth"]
m0 = simulations[1]["parms"]["m0"]
eps = simulations[1]["parms"]["eps"]

label_sim1 = fr'Heisenberg $(\ell, m_0, \epsilon) = ({l}, {m0}, {eps})$'
ax.plot(timespan[:m]*vLR, simulations[1]["evs"][:m],
        label=label_sim1, color='red', linestyle='--', marker='D', linewidth=1)

# --- Inset: Delta courbe ---
weigthed_fidelity = np.array([abs(evs_obs_ex.expect[0][i] - simulations[1]["evs"][i])/abs(evs_obs_ex.expect[0][i])
                             for i in range(0, m)])
inset_ax = inset_axes(ax, width="40%", height="30%", loc='lower left', borderpad=3)
inset_ax.plot(timespan[:m]*vLR,weigthed_fidelity,
              color="black", linestyle='solid', linewidth=1)
inset_ax.set_title(r'$\Delta\ (\%/100)$', fontsize=10)

inset_ax.tick_params(labelsize=8)
inset_ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.6)

# --- Style global ---
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(direction='out', length=6, width=2, which='major', grid_alpha=0.6)
ax.grid(True, which='major', linestyle='--', linewidth=0.75, alpha=0.7)
ax.legend(frameon=False, loc='upper right')

# Axe secondaire en haut
ax1 = ax.twiny()
ax1.set_xlim(timespan[0], timespan[-1])
ax.set_xlabel(r'$t v_{\rm LR} \, [L]$')
ax1.set_xlabel(r'$t \, [{\rm arb. units}]$')

# Titre
plt.title(r'non-local Hamiltonian, $L={}$, $J_x={}$, $v_{{\rm LR}}={}$'.format(
    params['size'], 
    round(params['Jx'], 3), 
    round(vLR, 3)
))

plt.tight_layout()
# Out:
# /tmp/ipykernel_5545/782950438.py:53: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract time series (length m)
exact_data = evs_obs_ex.expect[0][:m]
simulation_data = simulations[1]["evs"][:m]

# Use real FFT for speed & clarity
fft_vals_ex = np.fft.rfft(exact_data)
fft_vals_sim = np.fft.rfft(simulation_data)

# Frequency axis (assumes unit sampling interval, change d=1/fs if needed)
fft_freqs = np.fft.rfftfreq(m, d=1)

# Compute amplitudes
amplitude_ex = np.abs(fft_vals_ex)
amplitude_sim = np.abs(fft_vals_sim)

# Optional: focus on a frequency window (e.g., up to index 100)
max_index = 10  # Adjust as needed

# Plot
plt.figure(figsize=(8, 4))
plt.plot(fft_freqs[:max_index], amplitude_ex[:max_index], label="Exact")
plt.plot(fft_freqs[:max_index], amplitude_sim[:max_index], label="Simulation", linestyle='--')
plt.title("FFT Comparison: non-local Hamiltonian")
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /home/tomas/miniconda3/lib/python3.12/site-packages/numpy/fft/_pocketfft.py:70: ComplexWarning: Casting complex values to real discards the imaginary part
#   r = pfi.execute(a, is_real, is_forward, fct)

# %%
(0.116-0.110)/0.110
# Out:
# 0.05454545454545459
